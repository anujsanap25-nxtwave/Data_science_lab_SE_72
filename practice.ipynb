# %% [markdown]
# <a href="https://colab.research.google.com/github/anujsanap25-nxtwave/Data_science_lab_SE_72/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World....")
# Out:
# Hello World....
